# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## relation_unique_id 개수 판별

# %%
df = pd.read_csv('D:\Scrapy\insta_crawling\sd_2.csv')

# %%
df
# Out:
#              start          end
# 0       1592890217   2660637054
# 1       7605159862   2660637054
# 2      38798127865   2660637054
# 3       1052896622   2660637054
# 4       1476936633   2660637054
# 5       1505046254   2660637054
# 6       6392673350   2660637054
# 7       2368581512   2660637054
# 8       7919968294   2660637054
# 9       6273010531   2660637054
# 10     13225452062   2660637054
# 11      2059127066   2660637054
# 12      2025333691   2660637054
# 13     39169942260   2660637054
# 14     11202841050   2660637054
# 15     25772360441   2660637054
# 16     29152146795   2660637054
# 17     27026031184   2660637054
# 18     24885578071   2660637054
# 19      1592890217   2660637054
# 20      1751671418   2660637054
# 21     10321423100   2278258458
# 22      1545476272   2278258458
# 23      7605159862   2660637054
# 24     38798127865   2660637054
# 25      1052896622   2660637054
# 26      1476936633   2660637054
# 27      8006090454   2278258458
# ...

# %%
len(list(map(str, list(np.unique(df)))))
# Out:
# 1972

# %% [markdown]
# ## post의 unique_id 개수 판별

# %%
df2 = pd.read_csv('D:\Scrapy\insta_crawling\jl_region.csv')

# %%
len(np.unique(df2['insta_id']))
# Out:
# 3079

# %% [markdown]
# ## concat

# %%
import os
import pandas as pd
os.chdir(r'D:\local\insta_profiling\data')

# %%
df = pd.read_csv('jl_post_1.csv')
df2 = pd.read_csv('jl_post_2.csv')
new_df = pd.concat([df, df2])

# %%
new_df.to_csv('jl_post.csv', index=False)

# %%
new_df
# Out:
#          shortcode              insta_id    inner_id            post_date  \
# 0      Bw--6JFFkE1                cyrano      114789  2019-05-03 11:45:47
# 1      BrZiJ9gFvdp                cyrano      114789  2018-12-15 16:05:40
# 2      BmaLQQbBxjP                cyrano      114789  2018-08-13 15:27:49
# 3      Blw0_aSBSWs                cyrano      114789  2018-07-28 14:04:25
# 4      BlruAQPhK-h                cyrano      114789  2018-07-26 14:27:10
# 5      BlW_Y5hBP20                cyrano      114789  2018-07-18 13:15:01
# 6      BlUV42TB7rT                cyrano      114789  2018-07-17 12:33:54
# 7      BX-0Xr5lt0N                cyrano      114789  2017-08-20 01:08:50
# 8      BX-iHpdFoMv                cyrano      114789  2017-08-19 22:29:22
# 9      BX9FsvxFHK9                cyrano      114789  2017-08-19 09:01:47
# 10     BV_SEVblNIp                cyrano      114789  2017-07-01 12:25:33
# 11     BTqdEHblaDS                cyrano      114789  2017-05-04 17:14:48
# ...

# %%
concat_df = pd.concat([df, df2, df3])

# %%
new_df = pd.DataFrame(columns = ['data'], data = set(concat_df['data']))

# %%
new_df.to_csv('sd_over1000.csv', index=False)
